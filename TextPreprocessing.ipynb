# %% [markdown]
# <a href="https://colab.research.google.com/github/Manal2005/Multimodel/blob/main/TextPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
import string,time
from textblob import TextBlob
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
dataset = pd.read_csv('/content/drive/MyDrive/CMU MOSEI/Audio/Raw 3/Raw3-2/train.csv', encoding = 'ISO-8859-1')
dataset.head()
# Out:
#   video_id  clip_id                                               text  \
# 0   238023        0                                             ['Hi']
# 1   238023        1  ['Im', 'Liz', 'and', 'Im', 'here', 'to', 'talk...
# 2   238023        2  ['This', 'is', 'a', 'movie', 'that', 'was', 'b...
# 3   238023        3                     ['umm', 'and', 'also', 'this']
# 4   238023        4                                     ['uhh', 'Wow']
#
#       label annotation   mode
# 0  0.000000    Neutral  train
# 1  0.000000    Neutral  train
# 2  0.000000    Neutral  train
# 3  0.000000    Neutral  train
# 4 -2.333333   Negative  train

# %%
unique_values_counts = dataset['annotation'].value_counts()
print("Unique values and their counts:")
print(unique_values_counts)
# Out:
# Unique values and their counts:
# annotation
# Positive    2095
# Negative    1702
# Neutral      957
# Name: count, dtype: int64

# %%
 dataset['text'].str.lower()
# Out:
# 0        he is the co-founder of rossen and vettese lim...
# 1        chairman glenn ives said that deloitte is very...
# 2        marks &amp; spencer came out on top with a sco...
# 3        no other supermarkets received scores that mer...
# 4        issf members advocate for improved fishing met...
#                                ...
# 23149                          like, is three not a felony
# 23150    like, can my three wives and i still vote in t...
# 23151    like, these are questions i should not need to...
# 23152                          and what does all this mean
# 23153    abc news recently reported that one in eight v...
# Name: text, Length: 23154, dtype: object

# %%
def remove_html(text):       #removing html
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

dataset['text'] = dataset['text'].apply(remove_html)

def remove_url(text):       #removing url
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

dataset['text'] = dataset['text'].apply(remove_url)

exclude = string.punctuation       #removing punctation
def remove_punc(text):
  return text.translate(str.maketrans('','',exclude))

dataset['text'] = dataset['text'].apply(remove_punc)


#def correct_spelling(text):        #spelling correction
  #return str(TextBlob(text).correct())

#dataset['text'] = dataset['text'].apply(correct_spelling)


def remove_emoji(text):  # removing emoji
    emoji_pattern = re.compile(
        u"[\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"  # other symbols
        u"\U000024C2-\U0001F251"  # enclosed characters
        "]+", flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

dataset['text'] = dataset['text'].apply(remove_emoji)

dataset['text'] = dataset['text'].apply(word_tokenize)

# %%
dataset.to_csv('/content/drive/MyDrive/CMU MOSEI/Label1_preprocessed.csv', index=False)
